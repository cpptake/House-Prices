# %% [markdown]
# # 背景
#
# 前回HousePriceを適当にこなしてみた結果
# 散々な結果であった。（Score：0.17405 順位：3064位/4513位）
#
# 今回は反省をいかして
#
# ・EDAちゃんとする。
# ・データクレンジングちゃんとする。
# ・パラメータ調整ちゃんとする。
# ・モデル選びちゃんとする。
#
# をコンセプトにモデル作成します。

# %%
#データ準備（前回と同じ）

import pandas as pd
import numpy as np
 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
 
train = pd.read_csv('dataset/train.csv') #学習データ
test = pd.read_csv('dataset/test.csv') #テストデータ
print('The size of the train data:' + str(train.shape))
print('The size of the test data:' + str(test.shape))
# Out:
# The size of the train data:(1460, 81)
# The size of the test data:(1459, 80)

# %%
train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# ...

# %% [markdown]
# やっぱりobject方（名義変数）が多いです。
# 前回はこれを無視して解析しましたが、精度上げるにはそんなこと言ってられないので
# を使って数値に変換します。

# %% [markdown]
# # データのクレンジング
#
# 下記でデータの型変更、欠損値の補間、削除などを実施する。
#
# データの型変更はLabelEncorderを利用して離散化したデータに変更します。

# %%
#train.shape[1]
#train.iloc[0:,1]
train.head
# Out:
# <bound method NDFrame.head of         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0        1          60         3         65.0     8450       1      2
# 1        2          20         3         80.0     9600       1      2
# 2        3          60         3         68.0    11250       1      2
# 3        4          70         3         60.0     9550       1      2
# 4        5          60         3         84.0    14260       1      2
# 5        6          50         3         85.0    14115       1      2
# 6        7          20         3         75.0    10084       1      2
# 7        8          60         3          NaN    10382       1      2
# 8        9          50         4         51.0     6120       1      2
# 9       10         190         3         50.0     7420       1      2
# 10      11          20         3         70.0    11200       1      2
# 11      12          60         3         85.0    11924       1      2
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()


for i in range(train.shape[1]):
    if train.iloc[0:,i].dtypes ==object:
        
        #教師データのobjectを離散化
        le.fit(list(train.iloc[:,i].values))
        #テストデータのobjectを離散化
        le.fit(list(test.iloc[:,i].values))
        
        train.iloc[:,i] = le.transform(list(train.iloc[:,i].values))
        test.iloc[:,i] = le.transform(list(test.iloc[:,i].values))
        
       #print("yes")
#        le.fit(train['LandSlope'])
    
    
    
#   print (i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-bb29f7c98c51> in <module>
#      11         le.fit(list(test.iloc[:,i].values))
#      12
# ---> 13         train.iloc[:,i] = le.transform(list(train.iloc[:,i].values))
#      14         test.iloc[:,i] = le.transform(list(test.iloc[:,i].values))
#      15
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py in transform(self, y)
#     255             return np.array([])
#     256
# --> 257         _, y = _encode(y, uniques=self.classes_, encode=True)
#     258         return y
#     259
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py in _encode(values, uniques, encode)
#     108         return _encode_python(values, uniques, encode)
#     109     else:
# --> 110         return _encode_numpy(values, uniques, encode)
#     111
#     112
#
# ...

# %%
test['LandSlope']
# Out:
# 0       Gtl
# 1       Gtl
# 2       Gtl
# 3       Gtl
# 4       Gtl
# 5       Gtl
# 6       Gtl
# 7       Gtl
# 8       Gtl
# 9       Gtl
# 10      Gtl
# 11      Gtl
# 12      Gtl
# 13      Gtl
# 14      Gtl
# 15      Gtl
# 16      Gtl
# 17      Gtl
# 18      Gtl
# 19      Mod
# 20      Gtl
# 21      Gtl
# 22      Gtl
# 23      Gtl
# 24      Gtl
# 25      Gtl
# 26      Gtl
# 27      Gtl
# 28      Gtl
# 29      Gtl
#        ...
# 1429    Gtl
# 1430    Gtl
# 1431    Gtl
# 1432    Gtl
# 1433    Gtl
# 1434    Mod
# 1435    Mod
# 1436    Mod
# 1437    Gtl
# 1438    Gtl
# 1439    Gtl
# 1440    Mod
# 1441    Gtl
# 1442    Gtl
# 1443    Gtl
# 1444    Gtl
# 1445    Gtl
# 1446    Gtl
# 1447    Gtl
# 1448    Gtl
# 1449    Gtl
# 1450    Gtl
# 1451    Mod
# 1452    Gtl
# 1453    Gtl
# 1454    Gtl
# 1455    Gtl
# 1456    Gtl
# 1457    Gtl
# 1458    Mod
# Name: LandSlope, Length: 1459, dtype: object

# %%
test.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      227
# LotArea            0
# Street             0
# Alley              0
# LotShape           0
# LandContour        0
# Utilities          0
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrType         0
# MasVnrArea        15
# ExterQual          0
# ExterCond          0
# Foundation         0
#                 ...
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# KitchenQual        0
# TotRmsAbvGrd       0
# Functional         0
# Fireplaces         0
# FireplaceQu        0
# GarageType         0
# GarageYrBlt       78
# GarageFinish       0
# GarageCars         1
# ...

# %% [markdown]
# LotFrontage、GarageYrBltについては欠損値が多すぎるので特徴量からはずし、
# 欠損値が少なかったMasVnrAreaについては最頻値で補います。

# %%
# MasVnrAreaには最頻値を代入
train.MasVnrArea.fillna(train.MasVnrArea.mode()[0], inplace=True)
test.MasVnrArea.fillna(test.MasVnrArea.mode()[0], inplace=True)
#train.MasVnrArea.fillna(train.MasVnrArea.median(), inplace=True)


# 欠損値補完がされたかを確認
#train.isnull().sum()
test.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      227
# LotArea            0
# Street             0
# Alley              0
# LotShape           0
# LandContour        0
# Utilities          0
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrType         0
# MasVnrArea         0
# ExterQual          0
# ExterCond          0
# Foundation         0
#                 ...
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# KitchenQual        0
# TotRmsAbvGrd       0
# Functional         0
# Fireplaces         0
# FireplaceQu        0
# GarageType         0
# GarageYrBlt       78
# GarageFinish       0
# GarageCars         1
# ...

# %%
train.drop(['LotFrontage','GarageYrBlt'],axis=1)
test.drop(['LotFrontage','GarageYrBlt'],axis=1)
# Out:
#         Id  MSSubClass  MSZoning  LotArea  Street  Alley  LotShape  \
# 0     1461          20         2    11622       1      2         3
# 1     1462          20         3    14267       1      2         0
# 2     1463          60         3    13830       1      2         0
# 3     1464          60         3     9978       1      2         0
# 4     1465         120         3     5005       1      2         0
# 5     1466          60         3    10000       1      2         0
# 6     1467          20         3     7980       1      2         0
# 7     1468          60         3     8402       1      2         0
# 8     1469          20         3    10176       1      2         3
# 9     1470          20         3     8400       1      2         3
# 10    1471         120         2     5858       1      2         0
# 11    1472         160         4     1680       1      2         3
# 12    1473         160         4     1680       1      2         3
# ...

# %% [markdown]
# 離散化,欠損値の補間を完了しました。
# これで特徴量として扱えます。
#
# ということで教師データとテストデータに分割します。

# %%
#教師データ、テストデータの分割

y_train = train['SalePrice']
X_train = train.drop(['Id','SalePrice','LotFrontage','GarageYrBlt'], axis=1)
X_test = test.drop(['LotFrontage','GarageYrBlt'], axis=1)

# %% [markdown]
# # 目的変数と説明変数の設定
#
# 目的変数の分布の確認、影響度の強い説明変数の調査を実施します。

# %%
#目的変数SalePriceの分布確認

sns.distplot(y_train,bins=30,label='SalePrice')

# %% [markdown]
# ここについて、前回正規分布していると言っていたのですが
# どうやら歪度がおかしいため、正規分布とは言えないそうです。。。
#
# logの関数で対数変換をすることで正規分布に変換できるみたいなので、その値を目的変数に利用することにします。

# %%
#y_trainを対数変換
y_train = np.log(y_train)

sns.distplot(y_train,bins=30,label='SalePrice')

# %% [markdown]
# お手本のような正規分布になりました。（そもそも補正前を正規分布と勘違いするほうが略）
#
# それではランダムフォレストを使って、重要度の高い特徴量を探していきます。

# %%
#ランダムフォレスト回帰木セット
from sklearn.ensemble import RandomForestRegressor as RFR
#rf = RFR(n_jobs=-1, n_estimators=100)
rf = RFR(n_estimators=80, max_features='auto')
rf.fit(X_train, y_train)

#sns.barplot(x=rf.feature_importances_[ranking], y=X_train.columns.values[ranking], orient='h')

#plot_feature_importances_(rf)
#sns.barplot(x=rf.feature_importances_, y=X_train.columns.values)
f, ax = plt.subplots(figsize=(11, 15))
sns.barplot(x=rf.feature_importances_, y=X_train.columns.values, orient='h')

#plt.show()

# %% [markdown]
# OverallQual（部屋のクオリティ）がダントツで影響度が高く
# 次いで、GrLivArea,TotalBsmtSF,GarageCars,,,,,,などが上がってます。
#
# わかりにくいので上から順番に並べ替えて上位20件のみ特徴量として使います。

# %%
#影響度の順番に並び替え 
org_sort = np.argsort(-rf.feature_importances_)

#f, ax = plt.subplots(figsize=(11, 19))
#sns.barplot(rf.feature_importances_[org_sort], y=X_train.columns.values[org_sort], orient='h')

X_train = X_train.iloc[:,org_sort[:20]]
X_test = X_test.iloc[:,org_sort[:20]]

X_train.head()
# Out:
#    OverallQual  GrLivArea  TotalBsmtSF  GarageCars  GarageArea  1stFlrSF  \
# 0            7       1710          856           2         548       856
# 1            6       1262         1262           2         460      1262
# 2            7       1786          920           2         608       920
# 3            7       1717          756           3         642       961
# 4            8       2198         1145           3         836      1145
#
#    BsmtFinSF1  YearBuilt  LotArea  GarageType  OverallCond  CentralAir  \
# 0         706       2003     8450           1            5           1
# 1         978       1976     9600           1            8           1
# 2         486       2001    11250           1            5           1
# 3         216       1915     9550           5            5           1
# 4         655       2000    14260           1            5           1
#
#    YearRemodAdd  MSZoning  2ndFlrSF  GarageFinish  BsmtUnfSF  Neighborhood  \
# ...

# %% [markdown]
# 各特徴量の中身を確認し、外れ値を削除します。

# %%
#目的変数と説明変数の2変量の関係を描画

#sns.pairplot(X_train)


fig = plt.figure(figsize=(20,12))

for i in range(20):
    
    #4×5のグラフを作成。
    ax = fig.add_subplot(4,5,i+1)
    #目的変数（SalePrice)をy軸に、説明変数をx軸にプロット
    sns.regplot(x=X_train.iloc[:,i], y=y_train)

plt.tight_layout()
plt.show()

# %% [markdown]
# 'GrLivArea','TotalBsmtSF','1stFlrSF','BsmtFinSF1'
# あたりに外れ値が存在しているので、削除します。
#
# （それ以外にも外れ値点在してますが、全部消すのめんどくさいので割愛します。）

# %%
# 'GrLivArea','TotalBsmtSF'の外れ値削除
Xmat = X_train
Xmat['SalePrice'] = y_train
#Xmat = Xmat.drop(Xmat[(Xmat['GrLivArea']>4500) & (Xmat['SalePrice']<13)].index)
#Xmat = Xmat.drop(Xmat[(Xmat['TotalBsmtSF']>4000) & (Xmat['SalePrice']<12.5)].index)
Xmat = Xmat.drop(Xmat[(Xmat['GrLivArea']>4500)].index)
Xmat = Xmat.drop(Xmat[(Xmat['TotalBsmtSF']>4000)].index)


# 結果を教師データに反映
y_train = Xmat['SalePrice']
X_train = Xmat.drop(['SalePrice'], axis=1)


# 外れ値除外できているか確認。
fig = plt.figure(figsize=(20,12))

for i in range(20):
    
    ax = fig.add_subplot(4,5,i+1)#4×5のグラフを作成。
    sns.regplot(x=X_train.iloc[:,i], y=y_train)

plt.tight_layout()
plt.show()

# %% [markdown]
# 外れ値消えてますね。
# '1stFlrSF','BsmtFinSF1'あたりの外れ値も一緒に消えてるので同じデータだったのでしょう。
#
# これで特徴量加工終了です。

# %% [markdown]
# # 回帰モデル作成とパラメータ調整
#
# 上記でEDA,データのクレンジングは終了したので、ここから回帰モデル作成のパートに入っていきたいと思います。
#
# 選択するアルゴリズムはコンペの説明欄で推奨されていた、ランダムフォレスト、XGBoost、汎化性能高そうなSVMを利用したいと思います。
#
# （本当はニューラルネットワーク使ってみたいんですが、次の機会にします。）

# %%
from sklearn.ensemble import RandomForestRegressor as RFR
import xgboost as XGB
from sklearn.svm import SVR

#ランダムフォレスト
rfr = RFR(n_jobs=-1, n_estimators=100)
rfr.fit(X_train,y_train)

#XGBoost
xgb = XGB.XGBRegressor()
xgb.fit(X_train,y_train)

#SVM
svr = SVR()
svr.fit(X_train,y_train)
# Out:
# C:\Users\takes\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\takes\Anaconda3\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# C:\Users\takes\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [17:12:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
# ...

# %% [markdown]
# 入りました。
# まずはランダムフォレストからGridSearchします。
# 選択するパラメータはタイタニックと同じにします。

# %%
#ランダムフォレストのパラメータ調整
from sklearn.model_selection import GridSearchCV

#パラメータを振る。水準は適当に決定
#rfr_param_grid = {'criterion':['gini','entropy'],
#              'n_estimators':[25, 100, 500, 1000, 2000],
#              'min_samples_split':[0.5, 2,4,10],
#              'min_samples_leaf':[1,2,4,10],
#              'max_features':[2,4,8],
#              'bootstrap':[True, False]
#              }

rfr_grid = GridSearchCV(rg,cv=5,param_grid = {'n_estimators':[25, 100, 500, 1000, 2000],
              'min_samples_split':[0.5, 2,4,10],
              'min_samples_leaf':[1,2,4,10],
              'max_features':[2,4,8],
              'bootstrap':[True, False]
              })

rfr_grid = rfr_grid.fit(X_train, y_train)
rfr_grid_best = rfr_grid.best_estimator_

print(rfr_grid.best_score_)
print("grid_best = ",rfr_grid_best)
print("best params = ",rfr_grid.best_params_)
# Out:
# C:\Users\takes\Anaconda3\lib\site-packages\sklearn\externals\joblib\externals\loky\process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# C:\Users\takes\Anaconda3\lib\site-packages\sklearn\externals\joblib\externals\loky\process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# C:\Users\takes\Anaconda3\lib\site-packages\sklearn\externals\joblib\externals\loky\process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# ...

# %%
# XGBoostのパラメータ調整

from sklearn.model_selection import GridSearchCV

#xgb_param_grid = {'max_depth': [2,4,6],
#                'n_estimators': [50,100,200],
#                 'gamma':[0.1, 0.5, 1.0],
#                 'min_child_weight':[1,3,5]
#                }
                
xgb_grid = GridSearchCV(xgb, cv=5, param_grid = {'max_depth': [2,4,6],
                'n_estimators': [50,100,200],
                 'gamma':[0.1, 0.5, 1.0],
                 'min_child_weight':[1,3,5]
                 })
xgb_grid = xgb_grid.fit(X_train, y_train)
xgb_grid_best = xgb_grid.best_estimator_


print(xgb_grid.best_score_)
print("grid_best = ",xgb_grid_best)
print("best params = ",xgb_grid.best_params_)
# Out:
# C:\Users\takes\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\takes\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\takes\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\takes\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\takes\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# ...

# %%
#SVMのパラメータ調整

from sklearn.model_selection import GridSearchCV

#svr_param_grid = {"C": [1e0, 1e1, 1e2, 1e3],
#                  "gamma": np.logspace(-2, 2, 5)}

                
svr_grid = GridSearchCV(svr, cv=5,
                    param_grid = {"C": [1e0, 1e1, 1e2, 1e3],
                    "gamma": np.logspace(-2, 2, 5)})
svr_grid = svr_grid.fit(X_train, y_train)
svr_grid_best = svr_grid.best_estimator_

print(svr_grid.best_score_)
print("grid_best = ",svr_grid_best)
print("best params = ",svr_grid.best_params_)
# Out:
# 0.0030417238348627727
# grid_best =  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=0.01,
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# best params =  {'C': 1.0, 'gamma': 0.01}

# %%
X_train2 = pd.DataFrame( {'rfr': rfr_grid.predict(X_train),
     'xgb': xgb_grid.predict(X_train).ravel(),
     'SVR': svr_grid.predict(X_train),
    })

# %%
X_train2.head()
# Out:
#          rfr        xgb        SVR
# 0  12.252168  12.257529  12.147948
# 1  12.104601  12.033244  12.032223
# 2  12.318075  12.255825  12.216659
# 3  11.868337  12.001565  11.949369
# 4  12.437569  12.605364  12.329195

# %% [markdown]
# testデータの欠損値処理するの忘れてました。。。
#
# 欠損値を中央値で補間します。

# %%
X_test.isnull().sum()
# Out:
# OverallQual     0
# GrLivArea       0
# TotalBsmtSF     1
# GarageCars      1
# GarageArea      1
# 1stFlrSF        0
# BsmtFinSF1      1
# YearBuilt       0
# LotArea         0
# GarageType      0
# OverallCond     0
# CentralAir      0
# YearRemodAdd    0
# MSZoning        0
# 2ndFlrSF        0
# GarageFinish    0
# BsmtUnfSF       1
# Neighborhood    0
# OpenPorchSF     0
# BsmtQual        0
# dtype: int64

# %%
#X_test.MasVnrArea.fillna(X_test.MasVnrArea.mode()[0], inplace=True)
X_test.TotalBsmtSF.fillna(X_test.TotalBsmtSF.median(), inplace=True)
X_test.GarageCars.fillna(X_test.GarageCars.median(), inplace=True)
X_test.GarageArea.fillna(X_test.GarageArea.median(), inplace=True)
X_test.BsmtFinSF1.fillna(X_test.BsmtFinSF1.median(), inplace=True)
X_test.BsmtUnfSF.fillna(X_test.BsmtUnfSF.median(), inplace=True)

X_test.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-219-cc37d93b00ab> in <module>
#       1 #X_test.MasVnrArea.fillna(X_test.MasVnrArea.mode()[0], inplace=True)
# ----> 2 X_test.TotalBsmtSF.fillna(X_test.TotalBsmtSF.median(), inplace=True)
#       3 X_test.GarageCars.fillna(X_test.GarageCars.median(), inplace=True)
#       4 X_test.GarageArea.fillna(X_test.GarageArea.median(), inplace=True)
#       5 X_test.BsmtFinSF1.fillna(X_test.BsmtFinSF1.median(), inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'TotalBsmtSF'

# %%
X_test.isnull().sum()
# Out:
# HouseStyle      0
# LowQualFinSF    0
# BsmtUnfSF       1
# GarageFinish    0
# GarageCars      1
# Electrical      0
# BsmtFinType1    0
# OverallCond     0
# MSZoning        0
# FireplaceQu     0
# OverallQual     0
# HeatingQC       0
# YearBuilt       0
# MSSubClass      0
# 1stFlrSF        0
# GarageType      0
# BsmtFinSF2      1
# LandSlope       0
# WoodDeckSF      0
# Foundation      0
# dtype: int64

# %% [markdown]
# 力技ですが、補間できました。

# %%
#ランダムフォレスト予測結果の出力
# Id取得
y_test = rfr_grid.predict(X_test)

Id = np.array(y_test["Id"]).astype(int)
#予測データとIdをデータフレームへ落とし込む
my_rf_solution = pd.DataFrame(y_test, Id, columns = ["SalePrice"])

# csvに書き出し
my_rf_solution.to_csv("my_rfr_2.csv", index_label = ["Id"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-214-ffa4b0f07dc1> in <module>
#       1 #ランダムフォレスト予測結果の出力
#       2 # Id取得
# ----> 3 y_test = rfr_grid.predict(X_test)
#       4
#       5 Id = np.array(y_test["Id"]).astype(int)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     116
#     117         # lambda, but not partial, allows help() to work with update_wrapper
# --> 118         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     119         # update the docstring of the returned function
#     120         update_wrapper(out, self.fn)
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in predict(self, X)
#     489         """
#     490         self._check_is_fitted('predict')
# --> 491         return self.best_estimator_.predict(X)
#     492
# ...

# %%
X_test.isnull().sum()
# Out:
# HouseStyle      0
# LowQualFinSF    0
# BsmtUnfSF       1
# GarageFinish    0
# GarageCars      1
# Electrical      0
# BsmtFinType1    0
# OverallCond     0
# MSZoning        0
# FireplaceQu     0
# OverallQual     0
# HeatingQC       0
# YearBuilt       0
# MSSubClass      0
# 1stFlrSF        0
# GarageType      0
# BsmtFinSF2      1
# LandSlope       0
# WoodDeckSF      0
# Foundation      0
# dtype: int64
